# %%
x = int(input("ingrese su edad: "))
if x < 18:
    print("lo siento, eres menor de edad")
else:
    x>= 18
    print("puedes pasar, disfruta")
# Out:
# puedes pasar, disfruta

# %%
colores = {"rojo": "red", "azul": "blue"}
x = str(input("diga un color"))
if x in colores:
    print(colores[x])
else:
    print("ese color no esta en el diccionario")
# Out:
# ese color no esta en el diccionario
