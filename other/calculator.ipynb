# %%
operadores = {
    "*": lambda x, y: x * y,
    "/": lambda x, y: x / y,
    "^": lambda x, y: x ** y,
    "+": lambda x, y: x + y,
    "-": lambda x, y: x - y
}

expresion = input("Escribe una expresion simple separada por espacios (binomio): ")
expresion = expresion.split(" ")

first = 0
second = 0

try:
    first = float(expresion[0])
    second = float(expresion[2])
except:
    print("Número invalido")
    exit()

funcion = operadores[expresion[1]]

if funcion is None:
    print("Operador invalido")
    exit()

print(f"El valor de tu expresión es {funcion(first, second)}.")
# Out:
# El valor de tu expresión es 335.0.

# %%
import math

operadores = {
    "{0}+{1}": lambda x, y: x + y,
    "{0}-{1}": lambda x, y: x - y,
    "{0}*{1}": lambda x, y: x * y,
    "{0}/{1}": lambda x, y: x / y,
    "mod({0},{1})": lambda x, y: x % y,
    "{0}^{1}": lambda x, y: x ** y,
    "log({0},{1})": lambda x, y: math.log(y, x),
    "ln({0})": lambda x: math.log(x, math.e),
    "sen({0})": lambda x: math.sin(x),
    "cos({0})": lambda x: math.cos(x),
    "tan({0})": lambda x: math.tan(x),
    "[{0}]": lambda x: math.floor(x),
    "({0})": lambda x: x,
}

def operador_variables(string: str):


expresion = input("Expresión: ")
# Out:
#   Cell In[2], line 22
#     expresion = input("Expresión: ")
#     ^
# IndentationError: expected an indented block after function definition on line 19
