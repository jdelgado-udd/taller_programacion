# %% [markdown]
# # CONTROL 6
#
# ## Parte I

# %%
class Persona:
    def __init__(self, rut, nombre, apellido, correo):
        self.rut = rut
        self.nombre = nombre
        self.apellido = apellido
        self.correo = correo
    
    def validarut(self):
        if len(self.rut) != 10:
            return False
        
        base = self.rut.split("-")[0][::-1]
        factor = 2
        suma = 0

        try:
            chequeo = self.rut[-1]
            
            if chequeo == "K":
                chequeo = "10"
            
            chequeo = int(chequeo)

            for valor in base:
                suma += int(valor) * factor
                factor += 1

                if factor > 7:
                    factor = 2
        except ValueError:
            return False
        
        return 11 - (suma % 11) == chequeo
    
    def __repr__(self):
        return f"Nombre: {self.nombre} {self.apellido} | Correo: {self.correo}"

class Alumno(Persona):
    def __init__(self, rut, nombre, apellido, correo, carrera, asignatura, nota1, nota2, nota3, asistencia):
        super().__init__(rut, nombre, apellido, correo)

        self.carrera = carrera
        self.asignatura = asignatura
        self.nota1 = nota1
        self.nota2 = nota2
        self.nota3 = nota3
        self.asistencia = asistencia
    
    def promedio(self):
        return round(sum([self.nota1, self.nota2, self.nota3]) / 3, 1)
    
    def situacion_academica(self):
        if self.promedio() >= 4 and self.asistencia >= 75:
            return "Aprobado"
        
        return "Reprobado"
    
    def necesita_apoyo(self):
        return self.promedio() < 4.5 or self.asistencia < 80
    
    def __repr__(self):
        return f"Alumn@: {self.nombre} {self.apellido} | Asignatura: {self.asignatura} | Promedio: {self.promedio()} | Asistencia: {self.asistencia}% | RUT válido: {self.validarut()}"

class Profesor(Persona):
    def __init__(self, rut, nombre, apellido, correo, departamento, asignatura, horas_contrato):
        super().__init__(rut, nombre, apellido, correo)

        self.departamento = departamento
        self.asignatura = asignatura
        self.horas_contrato = horas_contrato
    
    def tipo_contrato(self):
        if self.horas_contrato >= 20:
            return "Jornada Alta"
        
        return "Jornada Parcial"
    
    def __repr__(self):
        return f"Profesor@: {self.nombre} {self.apellido} | Asignatura: {self.asignatura} | Horas: {self.horas_contrato} | {self.tipo_contrato()} | RUT válido: {self.validarut()}"

# %% [markdown]
# ## Parte II

# %%
personas = []
alumnos = []
profesores = []

with open("personas_academicas.csv", "r") as archivo:
    estructura = archivo.readline().strip("\n").split(",")

    for linea in archivo.readlines():
        linea = linea.strip("\n").split(",")
        valores = {}

        for indice in range(len(estructura)):
            valores[estructura[indice]] = linea[indice]
        
        objeto = None

        if valores["tipo"] == "ALUMNO":
            objeto = Alumno(
                valores["rut"],
                valores["nombre"],
                valores["apellido"],
                valores["correo"],
                valores["carrera_departamento"],
                valores["asignatura"],
                float(valores["nota1"]),
                float(valores["nota2"]),
                float(valores["nota3"]),
                int(valores["asistencia"])
            )
            alumnos.append(objeto)
        
        if valores["tipo"] == "PROFESOR":
            objeto = Profesor(
                valores["rut"],
                valores["nombre"],
                valores["apellido"],
                valores["correo"],
                valores["carrera_departamento"],
                valores["asignatura"],
                int(valores["horas_contrato"])
            )
            profesores.append(objeto)
        
        # Fallback en caso de que no caiga en ninguna de las dos categorías.
        if objeto is None:
            objeto = Persona(
                valores["rut"],
                valores["nombre"],
                valores["apellido"],
                valores["correo"]
            )
        
        personas.append(objeto)

print(personas)
# Out:
# [Alumn@: Valentina Muñoz | Asignatura: Taller de Programación | Promedio: 6.1 | Asistencia: 92% | RUT válido: True, Alumn@: Martín Rojas | Asignatura: Taller de Programación | Promedio: 4.2 | Asistencia: 81% | RUT válido: True, Alumn@: Camila Fernández | Asignatura: Base de Datos | Promedio: 5.8 | Asistencia: 88% | RUT válido: True, Alumn@: Tomás Sepúlveda | Asignatura: Base de Datos | Promedio: 3.7 | Asistencia: 74% | RUT válido: True, Alumn@: Sofía Contreras | Asignatura: Desafíos de la Informática | Promedio: 6.7 | Asistencia: 96% | RUT válido: True, Alumn@: Benjamín Araya | Asignatura: Desafíos de la Informática | Promedio: 4.8 | Asistencia: 85% | RUT válido: True, Profesor@: Carolina Silva | Asignatura: Taller de Programación | Horas: 22 | Jornada Alta | RUT válido: True, Profesor@: Pablo Herrera | Asignatura: Base de Datos | Horas: 18 | Jornada Parcial | RUT válido: True, Profesor@: Marcela Vega | Asignatura: Desafíos de la Informática | Horas: 12 | Jornada Parcial | RUT válido: True]

# %% [markdown]
# ## Parte III

# %%
print(
    f"Total de personas cargadas: {len(personas)}",
    f"Total de alumnos: {len(alumnos)}",
    f"Total de profesores: {len(profesores)}",
    sep="\n"
)

# Tomaré la instrucción como un loop printeando las personas
# ya que la última instrucción de la parte anterior pidió
# el "print(personas)".
print("Personas:")
for persona in personas:
    print(persona)
# Out:
# Total de personas cargadas: 9
# Total de alumnos: 6
# Total de profesores: 3
# Personas:
# Alumn@: Valentina Muñoz | Asignatura: Taller de Programación | Promedio: 6.1 | Asistencia: 92% | RUT válido: True
# Alumn@: Martín Rojas | Asignatura: Taller de Programación | Promedio: 4.2 | Asistencia: 81% | RUT válido: True
# Alumn@: Camila Fernández | Asignatura: Base de Datos | Promedio: 5.8 | Asistencia: 88% | RUT válido: True
# Alumn@: Tomás Sepúlveda | Asignatura: Base de Datos | Promedio: 3.7 | Asistencia: 74% | RUT válido: True
# Alumn@: Sofía Contreras | Asignatura: Desafíos de la Informática | Promedio: 6.7 | Asistencia: 96% | RUT válido: True
# Alumn@: Benjamín Araya | Asignatura: Desafíos de la Informática | Promedio: 4.8 | Asistencia: 85% | RUT válido: True
# Profesor@: Carolina Silva | Asignatura: Taller de Programación | Horas: 22 | Jornada Alta | RUT válido: True
# Profesor@: Pablo Herrera | Asignatura: Base de Datos | Horas: 18 | Jornada Parcial | RUT válido: True
# Profesor@: Marcela Vega | Asignatura: Desafíos de la Informática | Horas: 12 | Jornada Parcial | RUT válido: True

# %% [markdown]
# ## Parte IV

# %%
rut_valido = 0
rut_invalido = 0

for persona in personas:
    valido = "RUT inválido"
    rut_invalido += 1

    if persona.validarut():
        valido = "RUT válido"
        rut_valido += 1
        rut_invalido -= 1

    print(f"{persona.nombre} {persona.apellido} - {valido}")

print(
    f"Personas con RUT válido: {rut_valido}",
    f"Personas con RUT inválido: {rut_invalido}",
    sep="\n"
)
# Out:
# Valentina Muñoz - RUT válido
# Martín Rojas - RUT válido
# Camila Fernández - RUT válido
# Tomás Sepúlveda - RUT válido
# Sofía Contreras - RUT válido
# Benjamín Araya - RUT válido
# Carolina Silva - RUT válido
# Pablo Herrera - RUT válido
# Marcela Vega - RUT válido
# Personas con RUT válido: 9
# Personas con RUT inválido: 0

# %% [markdown]
# ## Parte V

# %%
alumnos_aprobados = 0
alumnos_reprobados = 0

for alumno in alumnos:
    print(f"{alumno.nombre} {alumno.apellido} - {alumno.promedio()}")

for alumno in alumnos:
    if alumno.situacion_academica() == "Aprobado":
        alumnos_aprobados += 1
    else:
        alumnos_reprobados += 1

    print(f"{alumno.nombre} {alumno.apellido} - {alumno.situacion_academica()}")

print(
    f"Alumnos aprobados: {alumnos_aprobados}",
    f"Alumnos reprobados: {alumnos_reprobados}",
    sep="\n"
)

mejor_alumno = None
for alumno in alumnos:
    if mejor_alumno is None or mejor_alumno.promedio() < alumno.promedio():
        mejor_alumno = alumno

if mejor_alumno is not None:
    print(f"Mejor alumno: {mejor_alumno.nombre} {mejor_alumno.apellido} - {mejor_alumno.carrera} - Promedio: {mejor_alumno.promedio()}")
else:
    print("No hay mejor alumno.")
# Out:
# Valentina Muñoz - 6.1
# Martín Rojas - 4.2
# Camila Fernández - 5.8
# Tomás Sepúlveda - 3.7
# Sofía Contreras - 6.7
# Benjamín Araya - 4.8
# Valentina Muñoz - Aprobado
# Martín Rojas - Aprobado
# Camila Fernández - Aprobado
# Tomás Sepúlveda - Reprobado
# Sofía Contreras - Aprobado
# Benjamín Araya - Aprobado
# Alumnos aprobados: 5
# Alumnos reprobados: 1
# Mejor alumno: Sofía Contreras - Ingeniería Civil Informática - Promedio: 6.7

# %% [markdown]
# ## Parte VI

# %%
horas_contratadas = 0
profesor_sobreexplotado = None

for profesor in profesores:
    print(f"{profesor.nombre} {profesor.apellido} - {profesor.tipo_contrato()}")
    horas_contratadas += profesor.horas_contrato

    if profesor_sobreexplotado is None:
        profesor_sobreexplotado = profesor
    
    if profesor_sobreexplotado.horas_contrato < profesor.horas_contrato:
        profesor_sobreexplotado = profesor
    
    if profesor_sobreexplotado.horas_contrato == profesor.horas_contrato and sorted([profesor_sobreexplotado.nombre[0], profesor.nombre[0]])[0] == profesor.nombre[0]:
        profesor_sobreexplotado = profesor

print(f"Total de horas contratadas: {horas_contratadas}")
print(f"Profesor con más horas: {profesor_sobreexplotado.nombre} {profesor_sobreexplotado.apellido} - {profesor_sobreexplotado.asignatura} - {profesor_sobreexplotado.horas_contrato} horas")
# Out:
# Carolina Silva - Jornada Alta
# Pablo Herrera - Jornada Parcial
# Marcela Vega - Jornada Parcial
# Total de horas contratadas: 52
# Profesor con más horas: Carolina Silva - Taller de Programación - 22 horas

# %% [markdown]
# ## Parte VII

# %%
alumnos_por_asignatura = {}

for alumno in alumnos:
    if alumno.asignatura not in alumnos_por_asignatura:
        alumnos_por_asignatura[alumno.asignatura] = []
    
    alumnos_por_asignatura[alumno.asignatura].append(alumno)

for asignatura, alumnos_asignatura in alumnos_por_asignatura.items():
    suma = 0

    for alumno in alumnos_asignatura:
        suma += alumno.promedio()

    print(
        f"Asignatura: {asignatura}",
        f"Cantidad de alumnos: {len(alumnos_asignatura)}",
        f"Promedio del curso: {suma / len(alumnos_asignatura)}",
        sep="\n"
    )
# Out:
# Asignatura: Taller de Programación
# Cantidad de alumnos: 2
# Promedio del curso: 5.15
# Asignatura: Base de Datos
# Cantidad de alumnos: 2
# Promedio del curso: 4.75
# Asignatura: Desafíos de la Informática
# Cantidad de alumnos: 2
# Promedio del curso: 5.75

# %% [markdown]
# ## Parte VIII

# %%
profesor_por_asignatura = {}

for profesor in profesores:
    profesor_por_asignatura[profesor.asignatura] = profesor

for asignatura, profesor in profesor_por_asignatura.items():
    print(
        f"Asignatura: {asignatura}",
        f"Profesor@: {profesor.nombre} {profesor.apellido}",
        "Alumnos:",
        sep="\n"
    )

    for alumno in alumnos_por_asignatura[asignatura]:
        print(f"- {alumno.nombre} {alumno.apellido} | Promedio: {alumno.promedio()} | {alumno.situacion_academica()}")
# Out:
# Asignatura: Taller de Programación
# Profesor@: Carolina Silva
# Alumnos:
# - Valentina Muñoz | Promedio: 6.1 | Aprobado
# - Martín Rojas | Promedio: 4.2 | Aprobado
# Asignatura: Base de Datos
# Profesor@: Pablo Herrera
# Alumnos:
# - Camila Fernández | Promedio: 5.8 | Aprobado
# - Tomás Sepúlveda | Promedio: 3.7 | Reprobado
# Asignatura: Desafíos de la Informática
# Profesor@: Marcela Vega
# Alumnos:
# - Sofía Contreras | Promedio: 6.7 | Aprobado
# - Benjamín Araya | Promedio: 4.8 | Aprobado

# %% [markdown]
# ## Parte IX

# %%
print("Alumnos que necesitan apoyo académico:")

for alumno in alumnos:
    if alumno.necesita_apoyo():
        print(f"{alumno.nombre} {alumno.apellido} - {alumno.promedio()} - {alumno.asistencia}%")
# Out:
# Alumnos que necesitan apoyo académico:
# Martín Rojas - 4.2 - 81%
# Tomás Sepúlveda - 3.7 - 74%
