# %%
sample_file = open("../data/sample.txt")

# %%
lines = sample_file.readlines()
lines
# Out:
# ['Cats are goated.\n', 'Dogs are too, but not so much.']

# %%
len(lines)
# Out:
# 2

# %%
names_file = open("../data/names.txt", "r+")
names = names_file.read().split(",")

names
# Out:
# ['Juan', 'Felipe', 'Amaia', 'Ignacio', 'Joaco']

# %%
names[2]
# Out:
# 'Amaia'

# %%
names[len(names) - 1] = "Joaco"
names
# Out:
# ['Juan', 'Felipe', 'Amaia', 'Ignacio', 'Joaco']

# %%
names_file.truncate(0)
names_file.write(",".join(names))

names_file.close()
