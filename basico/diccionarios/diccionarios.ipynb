# %% [markdown]
# # Diccionarios
#
# Una lista de asignaciones, es decir, una lista de valores que llevan a otro.
#
# Formato: `{ a: b, c: d }`

# %%
diccionario = {
    5: "Chao",
    0: "Hola",
    "Mai": "Se quiere morir",
    "Javi": "Hace ciberbullying",
    False: "TuPutaMadre",
    True: "Lopez"
}

diccionario[True]
# Out:
# 'Lopez'
