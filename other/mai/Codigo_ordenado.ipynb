# %% [markdown]
# # Clases

# %%
# Copia aquí las clases Personas, Alumno y Profesor sin modificaciones.

# %% [markdown]
# # Variables

# %%
# Variables globales
profesores=[]
alumnos=[]
personas=[]

acum_personas=0
acum_alumnos=0
acum_profesores=0
rutValido=0
rutInvalidou=0
alumnos_aprobados=0
alumnos_reprobados=0
mejorPromedio=0
mejorAlumno=None
totalHoras=0
mejorHoras=''
mejorProfe=''
alumnos_por_asignatura={}
profesores_por_asignatura={}

# %% [markdown]
# # Lectura CSV

# %%
# Pega aquí el bloque with open(...) que crea alumnos y profesores.

# %% [markdown]
# # Validación RUT

# %%
# Pega aquí el bloque de validación de RUT.

# %% [markdown]
# # Mostrar personas

# %%
# Pega aquí el bloque que imprime todas las personas.

# %% [markdown]
# # Información alumnos

# %%
# Pega aquí todos los cálculos de alumnos.

# %% [markdown]
# # Información profesores

# %%
# Pega aquí todos los cálculos de profesores.

# %% [markdown]
# # Agrupar por asignatura

# %%
# Pega aquí el código para alumnos_por_asignatura y profesores_por_asignatura.

# %% [markdown]
# # Reporte por asignatura

# %%
# Pega aquí el bloque corregido que imprime cada asignatura.

# %% [markdown]
# # Resumen final

# %%
# Pega aquí todos los print finales y necesita_apoyo().
