# %% [markdown]
# # Condiciones
#
# Son comparaciones, básicamente álgebra booleana. Retornan verdadero o falso.

# %% [markdown]
# # Igual
#
# Revisa si dos variables son iguales.
#
# Formato: `(primera variable) == (segunda variable)`
#
# IMPORTANTE: NO CONFUNDIR CON ASIGNACIÓN: `a = b`

# %%
a = 1
b = 2

a == b
# Out:
# False
